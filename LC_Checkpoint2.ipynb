# %%
#import all programs and files
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df1 = pd.read_csv('/Users/allisoncannady/Downloads/whs2022_annex2_pt1.csv')
df2 = pd.read_csv('/Users/allisoncannady/Downloads/whs2022_annex2_pt2.csv')
df3 = pd.read_csv('/Users/allisoncannady/Downloads/whs2022_annex2_pt3.csv')
df4 = pd.read_csv('/Users/allisoncannady/Downloads/whs2022_annex2_pt4.csv')

# %%
# World Health Statistics 2022
# Tables of health statistics by country, WHO region and globally
#df1 --> 
#df2 -->

# %%
# display first 10 rows
df1.head(10)
# Out:
#             Unnamed: 0                Unnamed: 1 Unnamed: 2  Unnamed: 3  \
# 0                  NaN  Total populationa (000s)        NaN         NaN
# 1            Data type      Comparable estimates        NaN         NaN
# 2                  NaN                      Male     Female  Both sexes
# 3         Member State                      2020        NaN         NaN
# 4          Afghanistan                    19 976     18 952      38 928
# 5              Albania                     1 465      1 413       2 878
# 6              Algeria                    22 154     21 697      43 851
# 7              Andorra                         -          -          77
# 8               Angola                    16 261     16 605      32 866
# 9  Antigua and Barbuda                        47         51          98
#
#                           Unnamed: 4 Unnamed: 5  Unnamed: 6  \
# 0  Life expectancy at birthb (years)        NaN         NaN
# ...

# %%
#look at number of rows and columns... table has 22 columns and 208 rows
df1.shape
# Out:
# (208, 22)

# %%
#look at column names... will need to re-name all the columns
df1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        '3.1', 'Unnamed: 11', 'Unnamed: 12', '3.2', 'Unnamed: 14', '3.3',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21'],
#       dtype='object')

# %%
#count number of rows....Unnamed: 18 can be deleted
df1.count()
# Out:
# Unnamed: 0     204
# Unnamed: 1     206
# Unnamed: 2     202
# Unnamed: 3     202
# Unnamed: 4     206
# Unnamed: 5     202
# Unnamed: 6     202
# Unnamed: 7     206
# Unnamed: 8     202
# Unnamed: 9     202
# 3.1            205
# Unnamed: 11    205
# Unnamed: 12    106
# 3.2            205
# Unnamed: 14    205
# 3.3            205
# Unnamed: 16    205
# Unnamed: 17    205
# Unnamed: 18      2
# Unnamed: 19    205
# Unnamed: 20    205
# Unnamed: 21    203
# dtype: int64

# %%
# get overall info about data and null values
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   204 non-null    object
#  1   Unnamed: 1   206 non-null    object
#  2   Unnamed: 2   202 non-null    object
#  3   Unnamed: 3   202 non-null    object
#  4   Unnamed: 4   206 non-null    object
#  5   Unnamed: 5   202 non-null    object
#  6   Unnamed: 6   202 non-null    object
#  7   Unnamed: 7   206 non-null    object
#  8   Unnamed: 8   202 non-null    object
#  9   Unnamed: 9   202 non-null    object
#  10  3.1          205 non-null    object
#  11  Unnamed: 11  205 non-null    object
#  12  Unnamed: 12  106 non-null    object
#  13  3.2          205 non-null    object
#  14  Unnamed: 14  205 non-null    object
#  15  3.3          205 non-null    object
#  16  Unnamed: 16  205 non-null    object
#  17  Unnamed: 17  205 non-null    object
# ...

# %%
##check null values....Unnamed 12 and Unnamed 18 could possibly go due to high amount of null values
df1.isnull().sum()
# Out:
# Unnamed: 0       4
# Unnamed: 1       2
# Unnamed: 2       6
# Unnamed: 3       6
# Unnamed: 4       2
# Unnamed: 5       6
# Unnamed: 6       6
# Unnamed: 7       2
# Unnamed: 8       6
# Unnamed: 9       6
# 3.1              3
# Unnamed: 11      3
# Unnamed: 12    102
# 3.2              3
# Unnamed: 14      3
# 3.3              3
# Unnamed: 16      3
# Unnamed: 17      3
# Unnamed: 18    206
# Unnamed: 19      3
# Unnamed: 20      3
# Unnamed: 21      5
# dtype: int64

# %%
#look at repeating values in each column...not helpful?
df1['Unnamed: 0'].value_counts()
# Out:
# Data type    1
# Portugal     1
# Norway       1
# Oman         1
# Pakistan     1
#             ..
# Greece       1
# Grenada      1
# Guatemala    1
# Guinea       1
# Global       1
# Name: Unnamed: 0, Length: 204, dtype: int64

# %%
#doesnt really help....
df1.describe()
# Out:
#        Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# count         204        206        202        202        206        202
# unique        204        195        192        200        136        133
# top     Data type          -          -         98          -          -
# freq            1         11         11          2         11         11
#
#        Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 12  3.2  \
# count         202        206        202        202  ...         106  205
# unique        138        127        123        127  ...           2   71
# top             -          -          -          -  ...          ak    4
# freq           11         11         11         11  ...          79   14
#
#        Unnamed: 14  3.3 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# count          205  205         205         205           2         205
# unique          42   62         123          80           2         110
# ...

# %%
# Plotting a scatter plot
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df[‘HP’], df[‘Price’])
ax.set_xlabel(‘HP’)
ax.set_ylabel(‘Price’)
plt.show()
# Out:
#   Input In [31]
#     ax.scatter(df[‘HP’], df[‘Price’])
#                   ^
# SyntaxError: invalid character '‘' (U+2018)

# %%
#cleaning = renaming columns

# %%
#Re-nameing columns... want to display info
df1.head()
# Out:
#      Unnamed: 0                Unnamed: 1 Unnamed: 2  Unnamed: 3  \
# 0           NaN  Total populationa (000s)        NaN         NaN
# 1     Data type      Comparable estimates        NaN         NaN
# 2           NaN                      Male     Female  Both sexes
# 3  Member State                      2020        NaN         NaN
# 4   Afghanistan                    19 976     18 952      38 928
#
#                           Unnamed: 4 Unnamed: 5  Unnamed: 6  \
# 0  Life expectancy at birthb (years)        NaN         NaN
# 1               Comparable estimates        NaN         NaN
# 2                               Male     Female  Both sexes
# 3                               2019        NaN         NaN
# 4                               63.3       63.2        63.2
#
#                                   Unnamed: 7 Unnamed: 8  Unnamed: 9  ...  \
# 0  Healthy life expectancy at birthb (years)        NaN         NaN  ...
# ...

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        '3.1', 'Unnamed: 11', 'Unnamed: 12', '3.2', 'Unnamed: 14', '3.3',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21'],
#       dtype='object')

# %%
#rename columns.. doesnt work to copy and paste becuase '' needs to be "" around each column title
df1 = df1.rename(columns= {'Unnamed: 0': "Country", 'Unnamed: 1': "Total Population Men", 'Unnamed: 2': "Total Population Women", 'Unnamed: 3': "Total Population Both", 'Unnamed: 4': "Life Expectancy at Birth Men (years)",
       'Unnamed: 5': "Life Expectancy at Birth Women (years)", 'Unnamed: 6': "Life Expectancy at Birth Both (years)", 'Unnamed: 7': "Healthy Life Expectancy at Birth Men (years)", 'Unnamed: 8': "Healthy Life Expectancy at Birth Women (years)", 'Unnamed: 9': "Healthy Life Expectancy at Birth Both (years)",
       '3.1': "", 'Unnamed: 11', 'Unnamed: 12', '3.2': "Under-five mortality rate (per 1000 live births", 'Unnamed: 14': "Neonatal mortality rate (per 1000 live births)", '3.3': "New HIV infectionsf (per 1000 uninfected population)",
       'Unnamed: 16': "Tuberculosis incidence (per 100 000 population)", 'Unnamed: 17': "Malaria incidenceh (per 1000 population at risk)", 'Unnamed: 18' , 'Unnamed: 19': "Hepatitis B surface antigen (HBsAg) prevalence...",
       'Unnamed: 20': "Reported number of people requiring intervention...", 'Unnamed: 21'})
# Out:
#   Input In [35]
#     '3.1': "", 'Unnamed: 11', 'Unnamed: 12', '3.2': "Under-five mortality rate (per 1000 live births", 'Unnamed: 14': "Neonatal mortality rate (per 1000 live births)", '3.3': "New HIV infectionsf (per 1000 uninfected population)",
#                             ^
# SyntaxError: invalid syntax

# %%
#success!
df1n = df1.rename(columns= {"Unnamed: 0": "Country", "Unnamed: 1": "Total Population Men", "Unnamed: 2": "Total Population Women", "Unnamed: 3": "Total Population Both", "Unnamed: 4": "Life Expectancy at Birth Men (years)",
       "Unnamed: 5": "Life Expectancy at Birth Women (years)", "Unnamed: 6": "Life Expectancy at Birth Both (years)", "Unnamed: 7": "Healthy Life Expectancy at Birth Men (years)", "Unnamed: 8": "Healthy Life Expectancy at Birth Women (years)", "Unnamed: 9": "Healthy Life Expectancy at Birth Both (years)",
       "3.1": "Unnamed: 3.1", "Unnamed: 11": "Unnamed: 11", "Unnamed: 12": "Unnamed: 12", "3.2": "Under-five mortality rate (per 1000 live births", "Unnamed: 14": "Neonatal mortality rate (per 1000 live births)", "3.3": "New HIV infections (per 1000 uninfected population)",
       "Unnamed: 16": "Tuberculosis incidence (per 100 000 population)", "Unnamed: 17": "Malaria incidenceh (per 1000 population at risk)", "Unnamed: 18": "Unnamed: 18" , "Unnamed: 19": "Hepatitis B surface antigen (HBsAg) prevalence...",
       "Unnamed: 20": "Reported number of people requiring intervention...", "Unnamed: 21": "Unnamed: 21"})

# %%
#look into column "Unnamed: 12" and "Unnamed: 18" to determine if need to delete. Delete for sure "Unnamed: 21" because its a repeat.
#Can delete row 0 because I changed the column names to represent their data. Could possibly delete row 1 also...will delete row 1.
#could change row 3 column 1 to years and then change NaN years to the appropriate year. Leave row 4 bc its helpful but could delete if info is in column title for all.
df1n.head()
# Out:
#         Country      Total Population Men Total Population Women  \
# 0           NaN  Total populationa (000s)                    NaN
# 1     Data type      Comparable estimates                    NaN
# 2           NaN                      Male                 Female
# 3  Member State                      2020                    NaN
# 4   Afghanistan                    19 976                 18 952
#
#   Total Population Both Life Expectancy at Birth Men (years)  \
# 0                   NaN    Life expectancy at birthb (years)
# 1                   NaN                 Comparable estimates
# 2            Both sexes                                 Male
# 3                   NaN                                 2019
# 4                38 928                                 63.3
#
#   Life Expectancy at Birth Women (years)  \
# 0                                    NaN
# 1                                    NaN
# 2                                 Female
# ...

# %%
#look at individual columns to figure out Unnamed: 12, 18...
df1["Unnamed: 12"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 208 entries, 0 to 207
# Series name: Unnamed: 12
# Non-Null Count  Dtype
# --------------  -----
# 106 non-null    object
# dtypes: object(1)
# memory usage: 1.8+ KB

# %%
df1["Unnamed: 12"].describe()
# Out:
# count     106
# unique      2
# top        ak
# freq       79
# Name: Unnamed: 12, dtype: object

# %%
df1["Unnamed: 12"].head(25)
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7      ak
# 8     NaN
# 9      ak
# 10    NaN
# 11     ak
# 12    al
# 13    al
# 14     ak
# 15     ak
# 16    al
# 17     ak
# 18     ak
# 19     ak
# 20    NaN
# 21     ak
# 22    NaN
# 23     ak
# 24     ak
# Name: Unnamed: 12, dtype: object

# %%
df1["Unnamed: 12"].count()
# Out:
# 106

# %%
#remove Unnamed: 12 due to too many null values and not helpful data
df1["Unnamed: 12"].isnull().sum()
# Out:
# 102

# %%
#looking at Unnamed: 18 to determine content and if need to delete
df1["Unnamed: 18"].head(25)
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# Name: Unnamed: 18, dtype: object

# %%
df1["Unnamed: 18"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 208 entries, 0 to 207
# Series name: Unnamed: 18
# Non-Null Count  Dtype
# --------------  -----
# 2 non-null      object
# dtypes: object(1)
# memory usage: 1.8+ KB

# %%
#delete Unnamed: 18 due to being mostly null values
df1["Unnamed: 18"].isnull().sum()
# Out:
# 206

# %%
#cleaning....
#remove unnecissary column Unnamed:21, Unnamed:12, Unnamed:18

# %%
#check for duplicate rows or data...
#Check for null values

# %%
#need to remove rows for data to be plotted...
df1nd = df1n.drop(df1n.index[[0, 1, 2, 3]], axis=0)
df1nd.head()
# Out:
#        Country Total Population Men Total Population Women  \
# 4  Afghanistan               19 976                 18 952
# 5      Albania                1 465                  1 413
# 6      Algeria               22 154                 21 697
# 7      Andorra                    -                      -
# 8       Angola               16 261                 16 605
#
#   Total Population Both Life Expectancy at Birth Men (years)  \
# 4                38 928                                 63.3
# 5                 2 878                                 76.3
# 6                43 851                                 76.2
# 7                    77                                    -
# 8                32 866                                 60.7
#
#   Life Expectancy at Birth Women (years)  \
# 4                                   63.2
# 5                                   79.9
# 6                                   78.1
# 7                                      -
# ...

# %%
#drop columns
df1nd.drop(['Unnamed: 12', 'Unnamed: 18', 'Unnamed: 21'], axis=1, inplace=True)
df1nd.head()
# Out:
#        Country Total Population Men Total Population Women  \
# 4  Afghanistan               19 976                 18 952
# 5      Albania                1 465                  1 413
# 6      Algeria               22 154                 21 697
# 7      Andorra                    -                      -
# 8       Angola               16 261                 16 605
#
#   Total Population Both Life Expectancy at Birth Men (years)  \
# 4                38 928                                 63.3
# 5                 2 878                                 76.3
# 6                43 851                                 76.2
# 7                    77                                    -
# 8                32 866                                 60.7
#
#   Life Expectancy at Birth Women (years)  \
# 4                                   63.2
# 5                                   79.9
# 6                                   78.1
# 7                                      -
# ...

# %%
#confirm that columns were dropped... but what is this new "unnamed: 3.1" and "Unnamed: 11"!?!?
df1nd.shape
# Out:
# (204, 19)

# %%
df1nd.rename(columns={"Unnamed: 3.1": "Neonatal mortality rate (per 1000 live births)", "Unnamed: 11": "Proportion of births attended by skilled health personnel (%)"}, inplace=True)
df1nd.head()
# Out:
#        Country Total Population Men Total Population Women  \
# 4  Afghanistan               19 976                 18 952
# 5      Albania                1 465                  1 413
# 6      Algeria               22 154                 21 697
# 7      Andorra                    -                      -
# 8       Angola               16 261                 16 605
#
#   Total Population Both Life Expectancy at Birth Men (years)  \
# 4                38 928                                 63.3
# 5                 2 878                                 76.3
# 6                43 851                                 76.2
# 7                    77                                    -
# 8                32 866                                 60.7
#
#   Life Expectancy at Birth Women (years)  \
# 4                                   63.2
# 5                                   79.9
# 6                                   78.1
# 7                                      -
# ...

# %%
#Visualizations...
#none of my plots work and I dont know why because the df1nd data frame is shown above and exists... why not defined?
#other plots dont work and I have looked up all the errors and it just gives me different errors when I try to fix them.
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#error says not defined but it is....
plt.scatter(x=df1nd['Country'], y=df1nd['Total Population Both'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [62], in <cell line: 2>()
#       1 #error says not defined but it is....
# ----> 2 plt.scatter(x=df1nd['Country'], y=df1nd['Total Population Both'])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2807, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2802 @_copy_docstring_and_deprecators(Axes.scatter)
#    2803 def scatter(
#    2804         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2805         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2806         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2807     __ret = gca().scatter(
#    2808         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
# ...

# %%
#country = df1nd['Country']
#tot_pop_both = df1nd['Total Population Both']

plt.scatter(x=df1nd[country], y=df1nd[tot_pop_both])

# %%
#detect outliers... wont work but could do for all of the columns.
#outliers stay and are very helpful data so wont delete but will prob make more visualizations on them in particular

sns.boxplot(x=df1nd['Life Expectancy at Birth Men (years)'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [65], in <cell line: 4>()
#       1 #detect outliers... wont work but could do for all of the columns.
#       2 #outliers stay and are very helpful data so wont delete but will prob make more visualizations on them in particular
# ----> 4 sns.boxplot(x=df1nd['Life Expectancy at Birth Men (years)'])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
#plot 2 variables... show countries in the x-axis then a specific column on the y-axis, such as occurence of TB
# Plotting a Histogram
df1nd.Make.value_counts().nlargest(40).plot(kind=’bar’, figsize=(10,5))
plt.title(“# TB cases Globally (thousands)")
plt.ylabel(‘cases of TB (thousands’)
plt.xlabel(‘Countries’);
# Out:
#   Input In [55]
#     df1nd.Make.value_counts().nlargest(40).plot(kind=’bar’, figsize=(10,5))
#                                                      ^
# SyntaxError: invalid character '’' (U+2019)

# %%
# Plotting a scatter plot
#vis_scatt_LE = df1nd['Life Expectancy at Birth Both (years)'].astype(int)

fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df1nd["Country"], df1nd["Life Expectancy at Birth Both (years)"])
ax.set_xlabel("Country")
ax.set_ylabel("Life Expectancy at Birth Both (years)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [56], in <cell line: 5>()
#       1 # Plotting a scatter plot
#       2 #vis_scatt_LE = df1nd['Life Expectancy at Birth Both (years)'].astype(int)
#       4 fig, ax = plt.subplots(figsize=(10,6))
# ----> 5 ax.scatter(df1nd["Country"], df1nd["Life Expectancy at Birth Both (years)"])
#       6 ax.set_xlabel("Country")
#       7 ax.set_ylabel("Life Expectancy at Birth Both (years)")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
# ...

# %%
df1nd["Life Expectancy at Birth Both (years)"] = [i for i in range(204)]
df1nd["Country"] = [i for i in range(204,204,204)]
# Plot
plt.scatter(x = "Life Expectancy at Birth Both (years)", y="Country", df1nd=df1nd ,color='#114a31',s = 25, alpha= 0.8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [57], in <cell line: 2>()
#       1 df1nd["Life Expectancy at Birth Both (years)"] = [i for i in range(204)]
# ----> 2 df1nd["Country"] = [i for i in range(204,204,204)]
#       3 # Plot
#       4 plt.scatter(x = "Life Expectancy at Birth Both (years)", y="Country", df1nd=df1nd ,color='#114a31',s = 25, alpha= 0.8)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
# ...

# %%
#compare 2 variables
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df1n["Country"], df1n["Life Expectancy at Birth Both (years)"])
ax.set_xlabel("Country")
ax.set_ylabel("Life Expectancy at Birth Both (years)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [58], in <cell line: 3>()
#       1 #compare 2 variables
#       2 fig, ax = plt.subplots(figsize=(10,6))
# ----> 3 ax.scatter(df1n["Country"], df1n["Life Expectancy at Birth Both (years)"])
#       4 ax.set_xlabel("Country")
#       5 ax.set_ylabel("Life Expectancy at Birth Both (years)")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# ...

# %%
sns.scatterplot(data= df1nd, x='Country', y='Total Population Both')
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Total Population Both'>

# %%
#df1nd.hist('Life Expectancy at Birth Both (years)')
#plt.show()

# %%
#Summarize Results

# %%
#1. Was there anything surprising about your dataset?
#yes. The excel file had merged column titles above the actual columns with data and that made the accessability of the data and its evaluation difficult. 
#I had to delete multiple rows and rename all the columns before I could even look at or pull anything up.
#The visulaizations did not work which is suprising and concerning. THe visualizaitons that did work are unreadable because the number of rows that need to be 
#displayed on the x-axis is too large?

# %%
#2. Do you have any concerns about your dataset?
#YES! I am concerned that I had to manipuate it so much that errors could have been introduced into the tables I want to work with
#and I will struggle later with pulling data and merging tables.
#I am also concerned that the way I visualized data in my head appearing might not look correct if 
#I am trying to display too many variables on the x-axis. 
#overall, I am very concerned that I am trying to use or merge too much data and that my cleaning of it will mess something up 
#that later in the process will not work. I might have selected a topic/file with to much data but nothing else in kaggle was interesting.

# %%
#3. Is there anything you want to make note of for the next phase of your analysis, which is cleaning data?.
#many things. I have a total of 4 tables/files that I have cleaned and that I want to merge into one file/page. I also want to change the titles of the
#columns to something shorter and then create a list of column descriptions at the beginning of the analysis for reference (for others to better understand)
