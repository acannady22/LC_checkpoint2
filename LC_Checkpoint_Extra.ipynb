# %%
#LC_Checkpoint2 extra data for tables 2-4

# %%
#import all programs and files
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df1 = pd.read_csv('/Users/allisoncannady/Downloads/whs2022_annex2_pt1.csv')
df2 = pd.read_csv('/Users/allisoncannady/Downloads/whs2022_annex2_pt2.csv')
df3 = pd.read_csv('/Users/allisoncannady/Downloads/whs2022_annex2_pt3.csv')
df4 = pd.read_csv('/Users/allisoncannady/Downloads/whs2022_annex2_pt4.csv')

# %%
#cleaning and re-naming columns in table 2 (df2)

# %%
#remove rows 0,1,2,3 and put years in the column names.
#make 0 the column name
#delete columns Unnamed: 6, Unnamed: 15, Unnamed: 16 
df2.head(10)
# Out:
#             Unnamed: 0                                                3.4  \
# 0                  NaN  Probability of dying from any of CVD, cancer, ...
# 1            Data type                               Comparable estimates
# 2                  NaN                                                NaN
# 3         Member State                                               2019
# 4          Afghanistan                                               35.3
# 5              Albania                                               11.4
# 6              Algeria                                               13.9
# 7              Andorra                                                  -
# 8               Angola                                               22.2
# 9  Antigua and Barbuda                                               17.5
#
#                                          Unnamed: 2  \
# 0  Suicide mortality ratek (per 100 000 population)
# ...

# %%
#check which columns to delete....Unnamed: 6, Unnamed: 15, Unnamed: 16 
df2.isnull().sum()
# Out:
# Unnamed: 0       4
# 3.4              3
# Unnamed: 2       3
# 3.5              3
# 3.6              3
# 3.7              3
# Unnamed: 6     157
# Unnamed: 7       3
# Unnamed: 8       4
# 3.8              3
# Unnamed: 10      3
# Unnamed: 11      3
# 3.9              3
# Unnamed: 13      3
# Unnamed: 14      3
# Unnamed: 15      5
# Unnamed: 16    208
# dtype: int64

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', '3.4', 'Unnamed: 2', '3.5', '3.6', '3.7', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', '3.8', 'Unnamed: 10', 'Unnamed: 11', '3.9',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16'],
#       dtype='object')

# %%
#rename columns
df2n = df2.rename(columns= {"Unnamed: 0": "Country", "3.4": "Probability of dying from any of CVD, cancer, diabetes, CRD between age 30 and exact age 70k (%)", "Unnamed: 2": "Suicide mortality ratek (per 100 000 population)", 
                            "3.5": "Total alcohol per capita (≥ 15 years of age) consumptionl (litres of pure alcohol)", "3.6": "Road traffic mortality rate (per 100 000 population)",
       "3.7": "Proportion of women of reproductive age who have their need for family planning satisfied with modern methodsm (%)", "Unnamed: 6": "Unnamed: 6", "Unnamed: 7": "Adolescent birth raten (per 1000 women aged 15–19 years)", 
                            "Unnamed: 8": "Adolescent birth raten (per 1000 women aged 10-14 years)", "3.8": "UHC: Service coverage index",
       "Unnamed: 10": "Population with household expenditures on health > 10% of total household expenditure or incomep (%)", 
                            "Unnamed: 11": "Population with household expenditures on health > 25% of total household expenditure or incomep (%) ", 
                            "3.9": "Age-standardized mortality rate attributed to household and ambient air pollutionq  (per 100 000 population) ", 
                            "Unnamed: 13": "Mortality rate attributed to exposure to unsafe WASH servicesr (per 100 000 population)", 
                            "Unnamed: 14": "Mortality rate from unintentional poisoningk (per 100 000 population)", 
                            "Unnamed: 15": "Unnamed: 15",
       "Unnamed: 16": "Unnamed: 16"})

# %%
df2n.head()
# Out:
#         Country  \
# 0           NaN
# 1     Data type
# 2           NaN
# 3  Member State
# 4   Afghanistan
#
#   Probability of dying from any of CVD, cancer, diabetes, CRD between age 30 and exact age 70k (%)  \
# 0  Probability of dying from any of CVD, cancer, ...
# 1                               Comparable estimates
# 2                                                NaN
# 3                                               2019
# 4                                               35.3
#
#    Suicide mortality ratek (per 100 000 population)  \
# 0  Suicide mortality ratek (per 100 000 population)
# 1                              Comparable estimates
# 2                                               NaN
# 3                                              2019
# 4                                               4.1
#
#   Total alcohol per capita (≥ 15 years of age) consumptionl (litres of pure alcohol)  \
# 0  Total alcohol per capita (≥ 15 years of age) c...
# ...

# %%
#drop columns... dropped then from original table df2n
#df2nd = df2n.drop(['Unnamed: 6', 'Unnamed: 15', 'Unnamed: 16'])
#df2nd.head()

# %%
df2n.head()
# Out:
#         Country  \
# 0           NaN
# 1     Data type
# 2           NaN
# 3  Member State
# 4   Afghanistan
#
#   Probability of dying from any of CVD, cancer, diabetes, CRD between age 30 and exact age 70k (%)  \
# 0  Probability of dying from any of CVD, cancer, ...
# 1                               Comparable estimates
# 2                                                NaN
# 3                                               2019
# 4                                               35.3
#
#    Suicide mortality ratek (per 100 000 population)  \
# 0  Suicide mortality ratek (per 100 000 population)
# 1                              Comparable estimates
# 2                                               NaN
# 3                                              2019
# 4                                               4.1
#
#   Total alcohol per capita (≥ 15 years of age) consumptionl (litres of pure alcohol)  \
# 0  Total alcohol per capita (≥ 15 years of age) c...
# ...

# %%
df2nd = df2n.drop(df2n.index[[0, 1, 2, 3]], axis=0)
df2nd.head()
# Out:
#        Country  \
# 4  Afghanistan
# 5      Albania
# 6      Algeria
# 7      Andorra
# 8       Angola
#
#   Probability of dying from any of CVD, cancer, diabetes, CRD between age 30 and exact age 70k (%)  \
# 4                                               35.3
# 5                                               11.4
# 6                                               13.9
# 7                                                  -
# 8                                               22.2
#
#   Suicide mortality ratek (per 100 000 population)  \
# 4                                              4.1
# 5                                              4.3
# 6                                              2.5
# 7                                                -
# 8                                              6.1
#
#   Total alcohol per capita (≥ 15 years of age) consumptionl (litres of pure alcohol)  \
# 4                                               <0.1
# ...

# %%
#Table 3...df3

# %%
df3.head()
# Out:
#      Unnamed: 0                                                3.a Unnamed: 2  \
# 0           NaN  Age-standardized prevalence of tobacco use amo...        NaN
# 1     Data type                               Comparable estimates        NaN
# 2           NaN                                                NaN        NaN
# 3  Member State                                               2020        NaN
# 4   Afghanistan                                               23.3        NaN
#
#                                                  3.b  \
# 0  Diphtheria-tetanus-pertussis (DTP3) immunizati...
# 1                               Comparable estimates
# 2                                                NaN
# 3                                               2020
# 4                                                 70
#
#                                           Unnamed: 4  \
# 0  Measles-containing-vaccine second-dose (MCV2) ...
# 1                               Comparable estimates
# ...

# %%
df3.columns
# Out:
# Index(['Unnamed: 0', '3.a', 'Unnamed: 2', '3.b', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', '3.c',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', '3.d', 'Unnamed: 15',
#        'Unnamed: 16', '1.a', 'Unnamed: 18', 'Unnamed: 19'],
#       dtype='object')

# %%
df3n = df3.rename(columns= {"Unnamed: 0": "Country", "3.a": "Age-standardized prevalence of tobacco use among persons 15 years and olders  (%) ", "Unnamed: 2": "Unnamed: 2", "3.b": "Diphtheria-tetanus-pertussis (DTP3) immunization coverage among 1-year-oldst (%)", "Unnamed: 4": "Measles-containing-vaccine second-dose (MCV2) immunization coverage by the nationally recommended aget (%) ",
       "Unnamed: 5": "Pneumococcal conjugate 3rd dose (PCV3) immunization coverage  among 1-year oldst (%)", "Unnamed: 6": "Human papillomavirus (HPV) immunization coverage estimates among 15 year-old girls (%)", "Unnamed: 7": "Total net official development assistance to medical research and basic health sectors per capitau (US$), by recipient country", "Unnamed: 8": "Proportion of health facilities with a core set of relevant essential medicines available and affordable on a sustainable basisv (%)", 
                            "Unnamed: 9": "Unnamed: 9",
       "3.c": "Density of medical doctorsw (per 10 000 population) ", "Unnamed: 11": "Density of nursing and midwifery personnelw (per 10 000 population) ", "Unnamed: 12": "Density of dentistsw (per 10 000 population) ", "Unnamed: 13": "Density of pharmacistsw (per 10 000 population) ", "3.d": "Average of 13 International Health Regulations core capacity scoresx", "Unnamed: 15": "Proportion of bloodstream infections due methicillin-resistant Staphylococcus aureusy (%)",
       "Unnamed: 16": "Proportion of bloodstream infection due to Escherichia coli resistant to 3rd-generation cephalosporiny (%)", 
                            "1.a": "Domestic general government health expenditure (GGHE-D) as percentage of general government expenditure (GGE)z (%)", "Unnamed: 18": "Unnamed: 18" , "Unnamed: 19": "Unnamed: 19"})
df3n.head()
# Out:
#         Country  \
# 0           NaN
# 1     Data type
# 2           NaN
# 3  Member State
# 4   Afghanistan
#
#   Age-standardized prevalence of tobacco use among persons 15 years and olders  (%)   \
# 0  Age-standardized prevalence of tobacco use amo...
# 1                               Comparable estimates
# 2                                                NaN
# 3                                               2020
# 4                                               23.3
#
#   Unnamed: 2  \
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
#   Diphtheria-tetanus-pertussis (DTP3) immunization coverage among 1-year-oldst (%)  \
# 0  Diphtheria-tetanus-pertussis (DTP3) immunizati...
# 1                               Comparable estimates
# 2                                                NaN
# 3                                               2020
# 4                                                 70
#
# ...

# %%
df3nd = df3n.drop(['Unnamed: 2', 'Unnamed: 9', 'Unnamed: 18', 'Unnamed: 19'], axis=1)
df3nd.head()
# Out:
#         Country  \
# 0           NaN
# 1     Data type
# 2           NaN
# 3  Member State
# 4   Afghanistan
#
#   Age-standardized prevalence of tobacco use among persons 15 years and olders  (%)   \
# 0  Age-standardized prevalence of tobacco use amo...
# 1                               Comparable estimates
# 2                                                NaN
# 3                                               2020
# 4                                               23.3
#
#   Diphtheria-tetanus-pertussis (DTP3) immunization coverage among 1-year-oldst (%)  \
# 0  Diphtheria-tetanus-pertussis (DTP3) immunizati...
# 1                               Comparable estimates
# 2                                                NaN
# 3                                               2020
# 4                                                 70
#
#   Measles-containing-vaccine second-dose (MCV2) immunization coverage by the nationally recommended aget (%)   \
# ...

# %%
df3nd.drop(df3nd.index[[0, 1, 2, 3]], axis=0, inplace=True)
df3nd.head()
# Out:
#        Country  \
# 4  Afghanistan
# 5      Albania
# 6      Algeria
# 7      Andorra
# 8       Angola
#
#   Age-standardized prevalence of tobacco use among persons 15 years and olders  (%)   \
# 4                                               23.3
# 5                                               22.4
# 6                                               21.0
# 7                                               31.8
# 8                                                  -
#
#   Diphtheria-tetanus-pertussis (DTP3) immunization coverage among 1-year-oldst (%)  \
# 4                                                 70
# 5                                                 98
# 6                                                  -
# 7                                                 99
# 8                                                 51
#
#   Measles-containing-vaccine second-dose (MCV2) immunization coverage by the nationally recommended aget (%)   \
# ...

# %%
#Table 4 ..... df4
df4.head()
# Out:
#      Unnamed: 0                                               2.2 Unnamed: 2  \
# 0           NaN  Prevalence of stunting in children under 5aa (%)        NaN
# 1     Data type                              Comparable estimates        NaN
# 2           NaN                                               NaN        NaN
# 3  Member State                                              2020        NaN
# 4   Afghanistan                                              35.1        NaN
#
#                                         Unnamed: 3 Unnamed: 4  \
# 0  Prevalence of wasting in children under 5aa (%)        NaN
# 1                                     Primary data        NaN
# 2                                              NaN        NaN
# 3                                        2012-2020        NaN
# 4                                              5.1      au,av
#
#                                           Unnamed: 5 Unnamed: 6  \
# ...

# %%
df4.columns
# Out:
# Index(['Unnamed: 0', '2.2', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', '5.2', 'Unnamed: 9', '6.1',
#        '6.2', 'Unnamed: 12', '6.3.1', '6.a', '7.1', 'Unnamed: 16', '11.6',
#        '16.1', 'GPW13', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
df4n = df4.rename(columns= {"Unnamed: 0": "Country", "2.2": "Prevalence of stunting in children under 5aa (%)", "Unnamed: 2": "Unnamed: 2", 
                            "Unnamed: 3": "Prevalence of wasting in children under 5aa (%)", "Unnamed: 4": "Unnamed: 4",
       "Unnamed: 5": "Prevalence of overweight in children under 5aa (%)", "Unnamed: 6": "Unnamed: 6", "Unnamed: 7": "Prevalence of anaemia in women of reproductive age (15–49 years)ab  (%)", 
                            "5.2": "Proportion of ever-partnered women and girls aged 15–49 years subjected to physical and/or sexual violence by a current or former intimate partner in the previous 12 months", 
                            "Unnamed: 9": "Proportion of ever-partnered women and girls aged 15–49 years subjected to physical and/or sexual violence by a current or former intimate partner in their lifetimeac (%) ",
       "6.1": "Proportion of population using safely-managed drinking-water servicesad (%) ", "6.2": "Proportion of population using safely-managed sanitation servicesad (%) ", 
                            "Unnamed: 12": "Proportion of population using a hand-washing facility with soap and waterad (%)", 
                            "6.3.1": "Proportion of safely treated domestic wastewater flows (%)", 
                            "6.a": "Amount of water- and sanitation-related official development assistance that is part of a government-coordinated spending planaf (constant 2020 US$ millions)", 
                            "7.1": "Proportion of population with primary reliance on clean fuels and technologyag (%)",
       "Unnamed: 16": "Unnamed: 16", 
                            "11.6": "Annual mean concentrations of fine particulate matter (PM2.5) in urban areasag (µg/m3)",
                            "16.1": "Mortality rate due to homicidek (per 100 000 population)" , "GPW13": "Number of cases of poliomyelitis caused by wild poliovirus (WPV)ah", "Unnamed: 20": "Age-standardized prevalence of hypertension among adults aged 30-79 yearsai (%)", "Unnamed: 21": "Prevalence of obesity among children and adolescents (5–19 years)aj (%)", "Unnamed: 22": "Age-standardized prevalence of obesity among adults (18+ years)aj (%)", "Unnamed: 23": "Unnamed: 23"})
df4n.head()
# Out:
#         Country  Prevalence of stunting in children under 5aa (%) Unnamed: 2  \
# 0           NaN  Prevalence of stunting in children under 5aa (%)        NaN
# 1     Data type                              Comparable estimates        NaN
# 2           NaN                                               NaN        NaN
# 3  Member State                                              2020        NaN
# 4   Afghanistan                                              35.1        NaN
#
#    Prevalence of wasting in children under 5aa (%) Unnamed: 4  \
# 0  Prevalence of wasting in children under 5aa (%)        NaN
# 1                                     Primary data        NaN
# 2                                              NaN        NaN
# 3                                        2012-2020        NaN
# 4                                              5.1      au,av
#
#   Prevalence of overweight in children under 5aa (%) Unnamed: 6  \
# ...

# %%
df4nd = df4n.drop(['Unnamed: 2', 'Unnamed: 4', 'Unnamed: 6', 'Unnamed: 16', 'Unnamed: 23'], axis=1)
df4nd.head()
# Out:
#         Country  Prevalence of stunting in children under 5aa (%)  \
# 0           NaN  Prevalence of stunting in children under 5aa (%)
# 1     Data type                              Comparable estimates
# 2           NaN                                               NaN
# 3  Member State                                              2020
# 4   Afghanistan                                              35.1
#
#    Prevalence of wasting in children under 5aa (%)  \
# 0  Prevalence of wasting in children under 5aa (%)
# 1                                     Primary data
# 2                                              NaN
# 3                                        2012-2020
# 4                                              5.1
#
#   Prevalence of overweight in children under 5aa (%)  \
# 0  Prevalence of overweight in children under 5aa...
# 1                               Comparable estimates
# 2                                                NaN
# ...

# %%
df4nd.drop(df4nd.index[[0, 1, 2, 3]], axis=0, inplace=True)
df4nd.head()
# Out:
#        Country Prevalence of stunting in children under 5aa (%)  \
# 4  Afghanistan                                             35.1
# 5      Albania                                              9.6
# 6      Algeria                                              9.3
# 7      Andorra                                                -
# 8       Angola                                             37.7
#
#   Prevalence of wasting in children under 5aa (%)  \
# 4                                             5.1
# 5                                             1.6
# 6                                             2.7
# 7                                               -
# 8                                             4.9
#
#   Prevalence of overweight in children under 5aa (%)  \
# 4                                                3.9
# 5                                               14.6
# 6                                               12.9
# 7                                                  -
# ...
